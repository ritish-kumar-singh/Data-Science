# %% [markdown]
# # Dictionary is mutable and key-value pair collection
# # It allows efficient data retrieval and modification
# # In Python version less than 3.7, dictionaries are unordered
# # In Python 3.7 and above, dictionaries are ordered

# %%
empty_dict={}

# %%
empty_dict
# Out:
# {}

# %%
type(empty_dict)
# Out:
# dict

# %%
student={
    "name":"John",
    "age":25,
    "grade":"A"
}

# %%
student
# Out:
# {'name': 'John', 'age': 25, 'grade': 'A'}

# %%
student["name"]
# Out:
# 'John'

# %%
student["age"]
# Out:
# 25

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student["name4"] # gives an error if key does not exist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 student["name4"] # gives an error if key does not exist
#
# KeyError: 'name4'

# %%
student.get("name")
# Out:
# 'John'

# %%
r=student.get("name4") # does not give an error if key does not exist - It returns None

# %%
print(r)
# Out:
# None

# %%
student["name"]="Rohan"

# %%
student["name"]
# Out:
# 'Rohan'

# %%
student.get("name")
# Out:
# 'Rohan'

# %%
student.values()
# Out:
# dict_values(['Rohan', 25, 'A'])

# %%
student.pop("grade")
# Out:
# 'A'

# %%
student
# Out:
# {'name': 'Rohan', 'age': 25}

# %%
student.items()
# Out:
# dict_items([('name', 'Rohan'), ('age', 25)])

# %%
for key,value in student.items():
    print(key,":",value)
# Out:
# name : Rohan
# age : 25

# %%
for key,value in student.items():
    print(f"{key} : {value}")
# Out:
# name : Rohan
# age : 25

# %%
student.update({"grade":"A"})

# %%
student
# Out:
# {'name': 'Rohan', 'age': 25, 'grade': 'A'}

# %%
dict2={"age":35, "city":"Delhi"}

# %%
student.update(dict2)

# %%
student
# Out:
# {'name': 'Rohan', 'age': 35, 'grade': 'A', 'city': 'Delhi'}

# %%
student.pop("Country","No country found")
# Out:
# 'No country found'

# %%
student
# Out:
# {'name': 'Rohan', 'age': 35, 'grade': 'A', 'city': 'Delhi'}

# %%
student.popitem() # removes last inserted element
# Out:
# ('city', 'Delhi')

# %%
student
# Out:
# {'name': 'Rohan', 'age': 35, 'grade': 'A'}

# %%
student.setdefault("name","No name")
# Out:
# 'Rohan'

# %%
student.setdefault("name1","No name")
# Out:
# 'No name'

# %%
student
# Out:
# {'name': 'Rohan', 'age': 35, 'grade': 'A', 'name1': 'No name'}

# %%
dict3=student.copy() #creates a shallow copy

# %%
dict3
# Out:
# {'name': 'Rohan', 'age': 35, 'grade': 'A', 'name1': 'No name'}

# %%
student
# Out:
# {'name': 'Rohan', 'age': 35, 'grade': 'A', 'name1': 'No name'}

# %%
dict3.clear()

# %%
dict3
# Out:
# {}

# %%
student
# Out:
# {'name': 'Rohan', 'age': 35, 'grade': 'A', 'name1': 'No name'}
