# %%
name="Harry"

# %%
name
# Out:
# 'Harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name
# Out:
# 'Harry'

# %%
name.endswith("ry")
# Out:
# True

# %%
name.endswith("ery")
# Out:
# False

# %%
name.lower()
# Out:
# 'harry'

# %%
name
# Out:
# 'Harry'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("r")
# Out:
# 2

# %%
len(name)
# Out:
# 5

# %%
s="   Hello   "

# %%
s.strip()
# Out:
# 'Hello'

# %%
s
# Out:
# '   Hello   '

# %%
s="Hello World"

# %%
s.replace("World","Python")
# Out:
# 'Hello Python'

# %%
s
# Out:
# 'Hello World'

# %%
s.split(" ")
# Out:
# ['Hello', 'World']

# %%
s[0:5]
# Out:
# 'Hello'

# %%
len(s)
# Out:
# 11

# %%
s[1:-1] #add length of string to the -ve idx
# Out:
# 'ello Worl'

# %%
s[1:10]
# Out:
# 'ello Worl'

# %%
s[-10:-1]
# Out:
# 'ello Worl'

# %%
s[1:10] #add length of string to -ve idx
# Out:
# 'ello Worl'
