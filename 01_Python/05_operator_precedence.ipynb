# %% [markdown]
# # PEMDAS
#    - Parenthesis ()
#    - Exponents **
#    - Multiplication * , Division / , Floor Division // , Modulus %
#    - Addition + , Subtraction -

# %%
result=10+2*3

# %%
result
# Out:
# 16

# %%
54*3/23+4-2**5
# Out:
# -20.956521739130434

# %%
54*3/23+4-32
# Out:
# -20.956521739130434

# %%
162/23+4-32
# Out:
# -20.956521739130434

# %%
7.043478260869565+4-32
# Out:
# -20.956521739130434

# %%
11.043478260869565-32
# Out:
# -20.956521739130437

# %%
-20.956521739130434
# Out:
# -20.956521739130434

# %% [markdown]
# # Order of Evaluation
#     - Exponetiation is evaluated right to left
#          2 ** 3 ** 2 = 2 ** 9 = 512
#     - Else everything is evaluated left to right
#          2 + 3 + 9 = 5 + 9 = 14
