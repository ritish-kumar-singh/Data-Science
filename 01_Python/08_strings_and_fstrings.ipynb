# %%
s="John"

# %%
s[1]
# Out:
# 'o'

# %%
s[0]='P' # Strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s[0]='P' # Strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
s.upper() # New string is created ; Original string remains the same
# Out:
# 'JOHN'

# %%
s
# Out:
# 'John'

# %%
name="John"
age=25
print("My name is {} and I am {} years old".format(name,age))
# Out:
# My name is John and I am 25 years old

# %%
print(f"My name is {name} and I am {age} years old") # f-string : Python 3.6 onwards
# Out:
# My name is John and I am 25 years old

# %%
pi=3.14159
print(f"Pi rounded to 2 decimal places: {pi:.2f}")
# Out:
# Pi rounded to 2 decimal places: 3.14

# %% [markdown]
# # Padding and Alignment

# %%
print(f"{'Python' : <10}")  # Left-align
print(f"{'Python' : >10}")  # Right-align
print(f"{'Python' : ^10}")  # Center-align
# Out:
# Python
#     Python
#   Python

# %%
# f-string is the most efficient way of formatting strings
