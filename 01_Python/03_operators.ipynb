# %%
a=11
b=5

# %%
a+b
# Out:
# 16

# %%
a-b
# Out:
# 6

# %%
a*b
# Out:
# 55

# %%
a/b #floating point number - always
# Out:
# 2.2

# %%
a//b #removes decimal - returns integer
# Out:
# 2

# %%
a%b
# Out:
# 1

# %%
2**5
# Out:
# 32

# %%
a==b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
c=3

# %%
a==c
# Out:
# False

# %%
a==c #is a equals to c
# Out:
# False

# %%
c
# Out:
# 3

# %%
a
# Out:
# 11

# %%
a!=c
# Out:
# True

# %%
b1=True
b2=False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %%
b1^b2 #xor -> different => True
# Out:
# True

# %%
a&b #converts to binary and then operates on bits
# Out:
# 1

# %%
b1&b2
# Out:
# False

# %%
a|b #converts to binary and then operates on bits
# Out:
# 15

# %%
a=45

# %%
a+=4

# %%
a
# Out:
# 49

# %%
a=45

# %%
a-=4

# %%
a
# Out:
# 41

# %%
a/=5

# %%
a
# Out:
# 8.2

# %%
a //= 5

# %%
a
# Out:
# 1.0

# %%
a*=4

# %%
a
# Out:
# 4.0

# %%
a=8
a //= 5

# %%
a
# Out:
# 1

# %%
a=2
a**=4

# %%
a
# Out:
# 16

# %%
a%=3

# %%
a
# Out:
# 1

# %%
lst=[1,2,3]
a=3

# %%
a in lst
# Out:
# True

# %%
a not in lst
# Out:
# False

# %%
a=9
b=9

# %%
a is b
# Out:
# True

# %%
a=[1,3,4]
