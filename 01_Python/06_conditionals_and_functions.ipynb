# %%
a=4

# %%
if(a>53):
    print("Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %%
a=41

if(a>50):
    print("Greater than 50")
elif(a>40):
    print("Greater than 40")
elif(a>30):
    print("Greater than 30")
else:
    print("Done!")
# Out:
# Greater than 40

# %%
def add(a,b):
    return a+b

# %%
print(add(3,5))
# Out:
# 8

# %%
def avg(a,b=6): # Default argument should be the rightmost argument
    return (a+b)/2

# %%
avg(10,5)
# Out:
# 7.5

# %%
avg(4)
# Out:
# 5.0

# %%
def greet(): # When a function does not contain a return statement => It is returning None
    print("Hello! Good Morning!!")

# %%
greet()
# Out:
# Hello! Good Morning!!

# %%
None # It is a reserved keyword
