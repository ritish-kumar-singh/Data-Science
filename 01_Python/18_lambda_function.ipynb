# %% [markdown]
# - Lambda function : Anonymous, single-expression function defined using the keyword lambda'
# - Syntax
#   - lambda arguments : expression

# %%
cube = lambda x: x*x*x

# %%
cube(3)
# Out:
# 27

# %%
s=lambda a,b:a+b

# %%
s(4,6)
# Out:
# 10
