# %%
l=[3,5,23,3]

# %%
l[0]
# Out:
# 3

# %%
l[1]
# Out:
# 5

# %%
l[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 l[7]
#
# IndexError: list index out of range

# %% [markdown]
# # list is mutable

# %%
l[0]=4

# %%
l
# Out:
# [4, 5, 23, 3]

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 23, 3, 9]

# %%
l2=[9,5]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 23, 3, 9, 9, 5]

# %%
l.insert(1,200)

# %%
l
# Out:
# [4, 200, 5, 23, 3, 9, 9, 5]

# %%
l.pop()
# Out:
# 5

# %%
l
# Out:
# [4, 200, 5, 23, 3, 9, 9]

# %%
l.pop(4)
# Out:
# 3

# %%
l
# Out:
# [4, 200, 5, 23, 9, 9]

# %%
number=l.pop(5)

# %%
number
# Out:
# 9

# %%
l
# Out:
# [4, 200, 5, 23, 9]

# %%
l.index(4)
# Out:
# 0

# %%
l.index(23)
# Out:
# 3

# %%
l.index(8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l.index(8)
#
# ValueError: 8 is not in list

# %%
l
# Out:
# [4, 200, 5, 23, 9]

# %%
l.append(4)

# %%
l
# Out:
# [4, 200, 5, 23, 9, 4]

# %%
l.count(4)
# Out:
# 2

# %%
l.reverse()

# %%
l
# Out:
# [4, 9, 23, 5, 200, 4]

# %%
l.sort() # sorts the original list

# %%
l
# Out:
# [4, 4, 5, 9, 23, 200]

# %%
sorted(l)
# Out:
# [4, 4, 5, 9, 23, 200]

# %%
l1=[8,1,4,6,3,0,9]

# %%
sorted(l1) # returns a new list which is sorted version of original list
# Out:
# [0, 1, 3, 4, 6, 8, 9]

# %%
l1
# Out:
# [8, 1, 4, 6, 3, 0, 9]

# %%
l3=sorted(l1)

# %%
l1
# Out:
# [8, 1, 4, 6, 3, 0, 9]

# %%
l3
# Out:
# [0, 1, 3, 4, 6, 8, 9]

# %%
y=[1,2,True,False,[3,4]]

# %%
y[1]
# Out:
# 2

# %%
y[3]
# Out:
# False

# %%
y[4]
# Out:
# [3, 4]

# %%
y[4][0]
# Out:
# 3

# %%
y
# Out:
# [1, 2, True, False, [3, 4]]

# %%
list1=[1,2,3,4,5]

# %%
list2=[6,7,8,9]

# %%
list1+list2 # list concatenation using + operator -> returns a new list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
if 3 in list1:
    print('yes')
# Out:
# yes

# %%
3 in list1
# Out:
# True

# %%
33 in list1
# Out:
# False

# %%
names="jack-jill-shubham-akshay"

# %%
names.split('-')
# Out:
# ['jack', 'jill', 'shubham', 'akshay']

# %%
names
# Out:
# 'jack-jill-shubham-akshay'

# %%
names_list=names.split("-")

# %%
names_list
# Out:
# ['jack', 'jill', 'shubham', 'akshay']

# %%
for name in names_list:
    print(name)
# Out:
# jack
# jill
# shubham
# akshay

# %%
len(l)
# Out:
# 6
