# %%
a=5

# %%
b=7

# %%
a+b
# Out:
# 12

# %%
name="Harry"

# %%
print("Hello World") # this will print Hello World on the screen
# Out:
# Hello World

# %%
#this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a="4566"
b="5677"

# %%
a+b
# Out:
# '45665677'

# %%
int(a)+int(b)  # Typecasting
# Out:
# 10243
