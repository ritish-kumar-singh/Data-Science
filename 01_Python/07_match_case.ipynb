# %%
code=2000

# %%
match(code):
    case 200: 
        print("Response Ok!")
    case 400:
        print("Bad Request")
    case 500:
        print("Internal Server Error")
    case _: # Default
        print("Unknown Response")

print("End of program")
# Out:
# Unknown Response
# End of program
