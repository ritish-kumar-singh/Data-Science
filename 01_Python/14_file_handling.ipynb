# %% [markdown]
# # File handling allows Python programs to read, write, and manipulate files stored on disk.

# %%
f=open("text.txt","r")

# %%
f.read()
# Out:
# 'Hello\nHii \nHow are you'

# %%
s="This is a nice way to learn"

# %%
f.close()

# %%
f=open("text1.txt","w")

# %%
f.write(s)
# Out:
# 27

# %%
f.close()

# %% [markdown]
# - To delete a file, we use os module
#      - os.remove("file.txt")

# %%
with open("text.txt","r") as file:  # no need to close the file - Best Practice
    content=file.read()
    print(content)
# Out:
# Hello
# Hii
# How are you

# %%
f=open("text.txt","r")

# %%
f.read()  #read all content
# Out:
# 'Hello\nHii \nHow are you'

# %%
f.close()

# %%
f=open("text.txt","r")

# %%
f.readline() #reads one line at a time - can use this in a while loop till end of file to read all lines
# Out:
# 'Hello\n'

# %%
f.close()

# %%
f=open("text.txt","r")

# %%
f.readlines() #read all lines into a list
# Out:
# ['Hello\n', 'Hii \n', 'How are you']

# %%
f.close()

# %%
f=open("text.txt","w")

# %%
f.write("Hello\nHii ") #overwrite
# Out:
# 10

# %%
f.close()

# %%
f=open("text.txt","a")

# %%
f.write("\nHow are you") #add content at end of file
# Out:
# 12

# %%
f.close()

# %%
import os
os.path.exists("text.txt") #checks if file exists
# Out:
# True

# %%
os.path.exists("text3.txt") #checks if file exists
# Out:
# False

# %%
os.remove("text1.txt") #deletes a file
